# %% [markdown]
# # Flow Based Chatbots
# - Rules Fix : Option by option : Decision Tree (No need of NLP)
#
# # NLP based flow Chatbot
# - ASk question :
#   - show my transaction: Transaction Data
#   - Order 2 large Pizza and 1 coca kola
# - These are nlp trained
#
# # Open Ended Chatbots:
# - Like chatgpt change conversation and theme

# %% [markdown]
# # ChatBot Implementation Options:
# - Using a Chatbot framework : Diaglog Flow Google
# - Custom Implementation :OpenAI API BERT, LLM's foundational models
#
# - DialogBox vs OPENAI API
# - pretrained model provided by diaglogbox
# - custom training and fine tuning with openAI API

# %% [markdown]
# # DialogBox ChatBot Implement : API FAST+Python : Retrieve Database accordingly
# - Requirements:
#   - Backlog -> Features we want in our product
#     - support payment chatbot, track a order by phone, customer name
#   - Decide MVP : Phase1 koun sa features
#     - place new order and track order by order id
# - DialogBox:
#   - Scope of Work: new order, track order, billing queries
#   - Questions -> API call karega -> response use
#   - STEPS:
#     - create new agent
#     - Intent: new order: track order: order add - Reading user input
#     - Intent is mapping between user input and action chatbot will do
#     - After Intent like add 2 pav bhai : Intent is add order
#     - Entity: API Call with {pavbhaji:2} food and number(NER) this went inside API
#       - Entity: Order_id, food_items:numbers
#     - From Dialog -> Intent->API and Entity:Kya figure out karna conversation se
#     - Create Intent -> Reponse and Training Phrases(track order) which recognize those intent
#     - Whenever user type track my order -> match track order -> intent pata
#       - Using NLP cosine similarity -> ML Model for intent classification
#     - Create Entity food items: own data pav bhaji chole bhautre
#     - Now intent-> Training data doge -> figure out entities
#     - Intent -> Action Jayega
#     - Intent -> Contexts
